# %%
# IMPORT POTREBNIH BIBLIOTEKA
import tensorflow as tf
import os
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import models, layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, BatchNormalization, Dropout, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Reshape

# %%
if tf.test.gpu_device_name():
    print('GPU je prepoznat:', tf.test.gpu_device_name())
else:
    print('GPU nije prepoznat.')
# Out:
# GPU je prepoznat: /device:GPU:0

# %%
#1. Definiranje putanje do glavnog direktorija
base_dir = r'C:\Users\Pc\Ana projekt\dataset'
train_dir = os.path.join(base_dir,'training')
val_dir = os.path.join(base_dir, 'validation')
test_dir = os.path.join(base_dir, 'test')

# Class names
class_names = ["Kocka", "Kugla", "Piramida", "Stozac", "Valjak"]

# %%
# ImageDataGenerator instances
train_datagen = ImageDataGenerator(
    rescale=1.0/255.,
    rotation_range=45,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='nearest'
)

val_test_datagen = ImageDataGenerator(rescale=1./255)

# Data generators
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(64, 64),
    batch_size=64,
    class_mode='categorical',
    shuffle=True
)

val_generator = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=(64, 64),
    batch_size=32,
    class_mode='categorical',
    shuffle=True
)

test_generator = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=(64, 64),
    batch_size=32,
    class_mode='categorical',
    shuffle=True
)
# Out:
# Found 2000 images belonging to 5 classes.
# Found 500 images belonging to 5 classes.
# Found 750 images belonging to 5 classes.

# %%
# Function to display images
def show_images(generator, class_names, num_images=5):
    images, labels = next(generator)
    fig, axes = plt.subplots(1, num_images, figsize=(15, 3))
    for i in range(num_images):
        axes[i].imshow(images[i])
        axes[i].set_title(class_names[np.argmax(labels[i])])
        axes[i].axis('off')
    plt.show()


# Display a few images from the training set
print("Training set:")
show_images(train_generator, class_names, num_images=5)

# Display a few images from the validation set
print("Validation set:")
show_images(val_generator, class_names, num_images=5)

# Display a few images from the test set
# print("Test set:")
# show_images(test_generator, class_names, num_images=5)

# GRAFOVI
def plot_model_accuracy(history):
  loss_train = history.history['accuracy']
  loss_val = history.history['val_accuracy']
  epochs = range(1, len(loss_train)+1)
  plt.plot(epochs, loss_train, 'g', label='Training accuracy')
  plt.plot(epochs, loss_val, 'b', label='validation accuracy')
  plt.title('Training and Validation accuracy')
  plt.xlabel('Epochs')
  plt.ylabel('Accuracy')
  plt.legend()
  plt.show()

def plot_model_loss(history):
  loss_train = history.history['loss']
  loss_val = history.history['val_loss']
  epochs = range(1, len(loss_train)+1)
  plt.plot(epochs, loss_train, 'g', label='Training loss')
  plt.plot(epochs, loss_val, 'b', label='validation loss')
  plt.title('Training and Validation loss')
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.legend()
  plt.show()
# Out:
# Training set:
# Validation set:

# %%
# Definisanje modela
model1 = Sequential()

# Prvi konvolucijski sloj
model1.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(64, 64, 3)))
model1.add(MaxPooling2D(pool_size=(2, 2)))
model1.add(layers.Dropout(0.2))

# Drugi konvolucijski sloj
model1.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model1.add(MaxPooling2D(pool_size=(2, 2)))
model1.add(layers.Dropout(0.2))

# Treći konvolucijski sloj
model1.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model1.add(MaxPooling2D(pool_size=(2, 2)))
model1.add(layers.Dropout(0.2))

# Flatten sloj za izravnjavanje rezultata iz konvolucionih slojeva
model1.add(Flatten())

# Fully connected sloj
model1.add(Dense(32, activation='relu'))

# Dodavanje Dropout sloja za smanjenje overfitting-a
model1.add(Dropout(0.5))

# Izlazni sloj
model1.add(Dense(5, activation='softmax'))

# Kompilacija modela
optimizer = Adam(learning_rate=0.0003)
model1.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Early stopping
callback = EarlyStopping(monitor='loss', patience=10, mode='min')

# Prikaz modela
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 62, 62, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 31, 31, 32)       0
#  )
#
#  dropout (Dropout)           (None, 31, 31, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 29, 29, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 14, 14, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 12, 12, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 6, 6, 128)         0
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dense (Dense)               (None, 32)                147488
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_1 (Dense)             (None, 5)                 165
#
# =================================================================
# Total params: 240,901
# Trainable params: 240,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Treniranje modela sa EarlyStopping callback-om
history = model1.fit(train_generator,
                     validation_data=val_generator,
                     steps_per_epoch=len(train_generator),
                     epochs=200,
                     validation_steps=len(val_generator),
                     callbacks=[callback],
                     verbose=2
)

# Save the model
model1.save('Ana-model3.h5')
# Out:
# Epoch 1/200
# 32/32 - 4s - loss: 1.6056 - accuracy: 0.2385 - val_loss: 1.5998 - val_accuracy: 0.2320 - 4s/epoch - 118ms/step
# Epoch 2/200
# 32/32 - 2s - loss: 1.5793 - accuracy: 0.2520 - val_loss: 1.5700 - val_accuracy: 0.2660 - 2s/epoch - 52ms/step
# Epoch 3/200
# 32/32 - 2s - loss: 1.5540 - accuracy: 0.2690 - val_loss: 1.5439 - val_accuracy: 0.3300 - 2s/epoch - 53ms/step
# Epoch 4/200
# 32/32 - 2s - loss: 1.5485 - accuracy: 0.2895 - val_loss: 1.5281 - val_accuracy: 0.3260 - 2s/epoch - 54ms/step
# Epoch 5/200
# 32/32 - 2s - loss: 1.5375 - accuracy: 0.2960 - val_loss: 1.5282 - val_accuracy: 0.3220 - 2s/epoch - 56ms/step
# Epoch 6/200
# 32/32 - 2s - loss: 1.5278 - accuracy: 0.2925 - val_loss: 1.5117 - val_accuracy: 0.3440 - 2s/epoch - 56ms/step
# Epoch 7/200
# 32/32 - 2s - loss: 1.5220 - accuracy: 0.3145 - val_loss: 1.5033 - val_accuracy: 0.3540 - 2s/epoch - 55ms/step
# Epoch 8/200
# 32/32 - 2s - loss: 1.5059 - accuracy: 0.3315 - val_loss: 1.4831 - val_accuracy: 0.3940 - 2s/epoch - 57ms/step
# Epoch 9/200
# 32/32 - 2s - loss: 1.4814 - accuracy: 0.3555 - val_loss: 1.4815 - val_accuracy: 0.3860 - 2s/epoch - 56ms/step
# Epoch 10/200
# 32/32 - 2s - loss: 1.4535 - accuracy: 0.3755 - val_loss: 1.4715 - val_accuracy: 0.3720 - 2s/epoch - 57ms/step
# Epoch 11/200
# 32/32 - 2s - loss: 1.4433 - accuracy: 0.3810 - val_loss: 1.4551 - val_accuracy: 0.4020 - 2s/epoch - 56ms/step
# Epoch 12/200
# 32/32 - 2s - loss: 1.4123 - accuracy: 0.3965 - val_loss: 1.3881 - val_accuracy: 0.4320 - 2s/epoch - 56ms/step
# Epoch 13/200
# 32/32 - 2s - loss: 1.4115 - accuracy: 0.3960 - val_loss: 1.4137 - val_accuracy: 0.4480 - 2s/epoch - 56ms/step
# Epoch 14/200
# 32/32 - 2s - loss: 1.3939 - accuracy: 0.4030 - val_loss: 1.3753 - val_accuracy: 0.4320 - 2s/epoch - 57ms/step
# Epoch 15/200
# 32/32 - 2s - loss: 1.3661 - accuracy: 0.4110 - val_loss: 1.3991 - val_accuracy: 0.4380 - 2s/epoch - 57ms/step
# Epoch 16/200
# 32/32 - 2s - loss: 1.3826 - accuracy: 0.3925 - val_loss: 1.4100 - val_accuracy: 0.4060 - 2s/epoch - 57ms/step
# Epoch 17/200
# 32/32 - 2s - loss: 1.3649 - accuracy: 0.4145 - val_loss: 1.3201 - val_accuracy: 0.4860 - 2s/epoch - 56ms/step
# Epoch 18/200
# 32/32 - 2s - loss: 1.3504 - accuracy: 0.4285 - val_loss: 1.3005 - val_accuracy: 0.4940 - 2s/epoch - 57ms/step
# Epoch 19/200
# 32/32 - 2s - loss: 1.3282 - accuracy: 0.4400 - val_loss: 1.3266 - val_accuracy: 0.4440 - 2s/epoch - 56ms/step
# Epoch 20/200
# 32/32 - 2s - loss: 1.3218 - accuracy: 0.4280 - val_loss: 1.3255 - val_accuracy: 0.4640 - 2s/epoch - 56ms/step
# Epoch 21/200
# 32/32 - 2s - loss: 1.2994 - accuracy: 0.4450 - val_loss: 1.2792 - val_accuracy: 0.4800 - 2s/epoch - 55ms/step
# Epoch 22/200
# 32/32 - 2s - loss: 1.3252 - accuracy: 0.4295 - val_loss: 1.2902 - val_accuracy: 0.4840 - 2s/epoch - 56ms/step
# Epoch 23/200
# 32/32 - 2s - loss: 1.3058 - accuracy: 0.4305 - val_loss: 1.2772 - val_accuracy: 0.4520 - 2s/epoch - 56ms/step
# Epoch 24/200
# 32/32 - 2s - loss: 1.3243 - accuracy: 0.4350 - val_loss: 1.2837 - val_accuracy: 0.4980 - 2s/epoch - 56ms/step
# Epoch 25/200
# 32/32 - 2s - loss: 1.2961 - accuracy: 0.4450 - val_loss: 1.2559 - val_accuracy: 0.5060 - 2s/epoch - 57ms/step
# Epoch 26/200
# 32/32 - 2s - loss: 1.2908 - accuracy: 0.4400 - val_loss: 1.2819 - val_accuracy: 0.4700 - 2s/epoch - 56ms/step
# Epoch 27/200
# 32/32 - 2s - loss: 1.2736 - accuracy: 0.4460 - val_loss: 1.2416 - val_accuracy: 0.5340 - 2s/epoch - 55ms/step
# Epoch 28/200
# 32/32 - 2s - loss: 1.2723 - accuracy: 0.4595 - val_loss: 1.2448 - val_accuracy: 0.5140 - 2s/epoch - 56ms/step
# Epoch 29/200
# 32/32 - 2s - loss: 1.2726 - accuracy: 0.4690 - val_loss: 1.2328 - val_accuracy: 0.4720 - 2s/epoch - 55ms/step
# Epoch 30/200
# 32/32 - 2s - loss: 1.2586 - accuracy: 0.4495 - val_loss: 1.2288 - val_accuracy: 0.4940 - 2s/epoch - 53ms/step
# Epoch 31/200
# 32/32 - 2s - loss: 1.2656 - accuracy: 0.4590 - val_loss: 1.2485 - val_accuracy: 0.4940 - 2s/epoch - 56ms/step
# Epoch 32/200
# 32/32 - 2s - loss: 1.2496 - accuracy: 0.4820 - val_loss: 1.2005 - val_accuracy: 0.5280 - 2s/epoch - 56ms/step
# Epoch 33/200
# 32/32 - 2s - loss: 1.2552 - accuracy: 0.4865 - val_loss: 1.2217 - val_accuracy: 0.5300 - 2s/epoch - 57ms/step
# Epoch 34/200
# 32/32 - 2s - loss: 1.2239 - accuracy: 0.4775 - val_loss: 1.1838 - val_accuracy: 0.5380 - 2s/epoch - 56ms/step
# Epoch 35/200
# 32/32 - 2s - loss: 1.2356 - accuracy: 0.4790 - val_loss: 1.2110 - val_accuracy: 0.5040 - 2s/epoch - 56ms/step
# Epoch 36/200
# 32/32 - 2s - loss: 1.2250 - accuracy: 0.4770 - val_loss: 1.1633 - val_accuracy: 0.5220 - 2s/epoch - 55ms/step
# Epoch 37/200
# 32/32 - 2s - loss: 1.2328 - accuracy: 0.4825 - val_loss: 1.1878 - val_accuracy: 0.5160 - 2s/epoch - 56ms/step
# Epoch 38/200
# 32/32 - 2s - loss: 1.1995 - accuracy: 0.4970 - val_loss: 1.2019 - val_accuracy: 0.5200 - 2s/epoch - 56ms/step
# Epoch 39/200
# 32/32 - 2s - loss: 1.2195 - accuracy: 0.4800 - val_loss: 1.1613 - val_accuracy: 0.5520 - 2s/epoch - 57ms/step
# Epoch 40/200
# 32/32 - 2s - loss: 1.1879 - accuracy: 0.4935 - val_loss: 1.1721 - val_accuracy: 0.5180 - 2s/epoch - 57ms/step
# Epoch 41/200
# 32/32 - 2s - loss: 1.1964 - accuracy: 0.5020 - val_loss: 1.1750 - val_accuracy: 0.5080 - 2s/epoch - 57ms/step
# Epoch 42/200
# 32/32 - 2s - loss: 1.2017 - accuracy: 0.4970 - val_loss: 1.1583 - val_accuracy: 0.5340 - 2s/epoch - 57ms/step
# Epoch 43/200
# 32/32 - 2s - loss: 1.1843 - accuracy: 0.5070 - val_loss: 1.1484 - val_accuracy: 0.5260 - 2s/epoch - 56ms/step
# Epoch 44/200
# 32/32 - 2s - loss: 1.1763 - accuracy: 0.5155 - val_loss: 1.1501 - val_accuracy: 0.5420 - 2s/epoch - 57ms/step
# Epoch 45/200
# 32/32 - 2s - loss: 1.1573 - accuracy: 0.5080 - val_loss: 1.1402 - val_accuracy: 0.5300 - 2s/epoch - 53ms/step
# Epoch 46/200
# 32/32 - 2s - loss: 1.1825 - accuracy: 0.5175 - val_loss: 1.1725 - val_accuracy: 0.5020 - 2s/epoch - 57ms/step
# Epoch 47/200
# 32/32 - 2s - loss: 1.1721 - accuracy: 0.5150 - val_loss: 1.1606 - val_accuracy: 0.5240 - 2s/epoch - 57ms/step
# Epoch 48/200
# 32/32 - 2s - loss: 1.1497 - accuracy: 0.5160 - val_loss: 1.1376 - val_accuracy: 0.5220 - 2s/epoch - 58ms/step
# Epoch 49/200
# 32/32 - 2s - loss: 1.1422 - accuracy: 0.5230 - val_loss: 1.1291 - val_accuracy: 0.5380 - 2s/epoch - 57ms/step
# Epoch 50/200
# 32/32 - 2s - loss: 1.1265 - accuracy: 0.5260 - val_loss: 1.0991 - val_accuracy: 0.5600 - 2s/epoch - 54ms/step
# Epoch 51/200
# 32/32 - 2s - loss: 1.1528 - accuracy: 0.5210 - val_loss: 1.0804 - val_accuracy: 0.5520 - 2s/epoch - 56ms/step
# Epoch 52/200
# 32/32 - 2s - loss: 1.1203 - accuracy: 0.5280 - val_loss: 1.1401 - val_accuracy: 0.5160 - 2s/epoch - 56ms/step
# Epoch 53/200
# 32/32 - 2s - loss: 1.1405 - accuracy: 0.5170 - val_loss: 1.1179 - val_accuracy: 0.5360 - 2s/epoch - 56ms/step
# Epoch 54/200
# 32/32 - 2s - loss: 1.1212 - accuracy: 0.5220 - val_loss: 1.0793 - val_accuracy: 0.5540 - 2s/epoch - 56ms/step
# Epoch 55/200
# 32/32 - 2s - loss: 1.1314 - accuracy: 0.5215 - val_loss: 1.1016 - val_accuracy: 0.5300 - 2s/epoch - 53ms/step
# Epoch 56/200
# 32/32 - 2s - loss: 1.0993 - accuracy: 0.5305 - val_loss: 1.0566 - val_accuracy: 0.5620 - 2s/epoch - 57ms/step
# Epoch 57/200
# 32/32 - 2s - loss: 1.1177 - accuracy: 0.5270 - val_loss: 1.0912 - val_accuracy: 0.5460 - 2s/epoch - 56ms/step
# Epoch 58/200
# 32/32 - 2s - loss: 1.1028 - accuracy: 0.5255 - val_loss: 1.1029 - val_accuracy: 0.5240 - 2s/epoch - 56ms/step
# Epoch 59/200
# 32/32 - 2s - loss: 1.1034 - accuracy: 0.5265 - val_loss: 1.0757 - val_accuracy: 0.5380 - 2s/epoch - 57ms/step
# Epoch 60/200
# 32/32 - 2s - loss: 1.0945 - accuracy: 0.5330 - val_loss: 1.0636 - val_accuracy: 0.5600 - 2s/epoch - 55ms/step
# Epoch 61/200
# 32/32 - 2s - loss: 1.0847 - accuracy: 0.5430 - val_loss: 1.0595 - val_accuracy: 0.5580 - 2s/epoch - 56ms/step
# Epoch 62/200
# 32/32 - 2s - loss: 1.0925 - accuracy: 0.5385 - val_loss: 1.0916 - val_accuracy: 0.5220 - 2s/epoch - 56ms/step
# Epoch 63/200
# 32/32 - 2s - loss: 1.0836 - accuracy: 0.5390 - val_loss: 1.0500 - val_accuracy: 0.5500 - 2s/epoch - 56ms/step
# Epoch 64/200
# 32/32 - 2s - loss: 1.0593 - accuracy: 0.5510 - val_loss: 1.0263 - val_accuracy: 0.5580 - 2s/epoch - 56ms/step
# Epoch 65/200
# 32/32 - 2s - loss: 1.0734 - accuracy: 0.5335 - val_loss: 1.0443 - val_accuracy: 0.5540 - 2s/epoch - 56ms/step
# Epoch 66/200
# 32/32 - 2s - loss: 1.0566 - accuracy: 0.5420 - val_loss: 1.0309 - val_accuracy: 0.5680 - 2s/epoch - 56ms/step
# Epoch 67/200
# 32/32 - 2s - loss: 1.0542 - accuracy: 0.5480 - val_loss: 0.9948 - val_accuracy: 0.5860 - 2s/epoch - 56ms/step
# Epoch 68/200
# 32/32 - 2s - loss: 1.0379 - accuracy: 0.5635 - val_loss: 1.0478 - val_accuracy: 0.5580 - 2s/epoch - 54ms/step
# Epoch 69/200
# 32/32 - 2s - loss: 1.0367 - accuracy: 0.5515 - val_loss: 1.0078 - val_accuracy: 0.5620 - 2s/epoch - 56ms/step
# Epoch 70/200
# 32/32 - 2s - loss: 1.0403 - accuracy: 0.5510 - val_loss: 1.0571 - val_accuracy: 0.5340 - 2s/epoch - 56ms/step
# Epoch 71/200
# 32/32 - 2s - loss: 1.0486 - accuracy: 0.5580 - val_loss: 1.0026 - val_accuracy: 0.5740 - 2s/epoch - 56ms/step
# Epoch 72/200
# 32/32 - 2s - loss: 1.0267 - accuracy: 0.5695 - val_loss: 0.9839 - val_accuracy: 0.5820 - 2s/epoch - 56ms/step
# Epoch 73/200
# 32/32 - 2s - loss: 1.0292 - accuracy: 0.5610 - val_loss: 0.9994 - val_accuracy: 0.5680 - 2s/epoch - 56ms/step
# Epoch 74/200
# 32/32 - 2s - loss: 1.0189 - accuracy: 0.5600 - val_loss: 1.0004 - val_accuracy: 0.5680 - 2s/epoch - 56ms/step
# Epoch 75/200
# 32/32 - 2s - loss: 1.0092 - accuracy: 0.5515 - val_loss: 0.9894 - val_accuracy: 0.5720 - 2s/epoch - 56ms/step
# Epoch 76/200
# 32/32 - 2s - loss: 1.0167 - accuracy: 0.5630 - val_loss: 1.0407 - val_accuracy: 0.5460 - 2s/epoch - 56ms/step
# Epoch 77/200
# 32/32 - 2s - loss: 1.0020 - accuracy: 0.5695 - val_loss: 0.9588 - val_accuracy: 0.6020 - 2s/epoch - 56ms/step
# Epoch 78/200
# 32/32 - 2s - loss: 0.9949 - accuracy: 0.5735 - val_loss: 0.9972 - val_accuracy: 0.5600 - 2s/epoch - 56ms/step
# Epoch 79/200
# 32/32 - 2s - loss: 0.9832 - accuracy: 0.5875 - val_loss: 0.9538 - val_accuracy: 0.5880 - 2s/epoch - 56ms/step
# Epoch 80/200
# 32/32 - 2s - loss: 0.9811 - accuracy: 0.5795 - val_loss: 1.0013 - val_accuracy: 0.5580 - 2s/epoch - 56ms/step
# Epoch 81/200
# 32/32 - 2s - loss: 1.0105 - accuracy: 0.5690 - val_loss: 1.0159 - val_accuracy: 0.5560 - 2s/epoch - 55ms/step
# Epoch 82/200
# 32/32 - 2s - loss: 0.9767 - accuracy: 0.5825 - val_loss: 0.9794 - val_accuracy: 0.5600 - 2s/epoch - 56ms/step
# Epoch 83/200
# 32/32 - 2s - loss: 0.9871 - accuracy: 0.5690 - val_loss: 0.9598 - val_accuracy: 0.5920 - 2s/epoch - 56ms/step
# Epoch 84/200
# 32/32 - 2s - loss: 0.9801 - accuracy: 0.5835 - val_loss: 0.9860 - val_accuracy: 0.5800 - 2s/epoch - 56ms/step
# Epoch 85/200
# 32/32 - 2s - loss: 0.9718 - accuracy: 0.5765 - val_loss: 1.0443 - val_accuracy: 0.5600 - 2s/epoch - 55ms/step
# Epoch 86/200
# 32/32 - 2s - loss: 0.9800 - accuracy: 0.5770 - val_loss: 0.9936 - val_accuracy: 0.5820 - 2s/epoch - 56ms/step
# Epoch 87/200
# 32/32 - 2s - loss: 0.9687 - accuracy: 0.5800 - val_loss: 0.9887 - val_accuracy: 0.5960 - 2s/epoch - 55ms/step
# Epoch 88/200
# 32/32 - 2s - loss: 0.9816 - accuracy: 0.5715 - val_loss: 0.9580 - val_accuracy: 0.6140 - 2s/epoch - 56ms/step
# Epoch 89/200
# 32/32 - 2s - loss: 0.9534 - accuracy: 0.5890 - val_loss: 0.9646 - val_accuracy: 0.6080 - 2s/epoch - 56ms/step
# Epoch 90/200
# 32/32 - 2s - loss: 0.9709 - accuracy: 0.5865 - val_loss: 0.9365 - val_accuracy: 0.6040 - 2s/epoch - 56ms/step
# Epoch 91/200
# 32/32 - 2s - loss: 0.9495 - accuracy: 0.5865 - val_loss: 0.9450 - val_accuracy: 0.6060 - 2s/epoch - 56ms/step
# Epoch 92/200
# 32/32 - 2s - loss: 0.9443 - accuracy: 0.5980 - val_loss: 0.9474 - val_accuracy: 0.6080 - 2s/epoch - 56ms/step
# Epoch 93/200
# 32/32 - 2s - loss: 0.9516 - accuracy: 0.5940 - val_loss: 0.9327 - val_accuracy: 0.6160 - 2s/epoch - 56ms/step
# Epoch 94/200
# 32/32 - 2s - loss: 0.9332 - accuracy: 0.5955 - val_loss: 0.9284 - val_accuracy: 0.6160 - 2s/epoch - 56ms/step
# Epoch 95/200
# 32/32 - 2s - loss: 0.9222 - accuracy: 0.6200 - val_loss: 0.9648 - val_accuracy: 0.6080 - 2s/epoch - 56ms/step
# Epoch 96/200
# 32/32 - 2s - loss: 0.9378 - accuracy: 0.5805 - val_loss: 0.9525 - val_accuracy: 0.6000 - 2s/epoch - 56ms/step
# Epoch 97/200
# 32/32 - 2s - loss: 0.9194 - accuracy: 0.6025 - val_loss: 0.9363 - val_accuracy: 0.6020 - 2s/epoch - 56ms/step
# Epoch 98/200
# 32/32 - 2s - loss: 0.9289 - accuracy: 0.5965 - val_loss: 0.9490 - val_accuracy: 0.5920 - 2s/epoch - 56ms/step
# Epoch 99/200
# 32/32 - 2s - loss: 0.9211 - accuracy: 0.5860 - val_loss: 0.9734 - val_accuracy: 0.5820 - 2s/epoch - 55ms/step
# Epoch 100/200
# 32/32 - 2s - loss: 0.9043 - accuracy: 0.6175 - val_loss: 0.8974 - val_accuracy: 0.6140 - 2s/epoch - 56ms/step
# Epoch 101/200
# 32/32 - 2s - loss: 0.9168 - accuracy: 0.5995 - val_loss: 0.9415 - val_accuracy: 0.6100 - 2s/epoch - 56ms/step
# Epoch 102/200
# 32/32 - 2s - loss: 0.9134 - accuracy: 0.6070 - val_loss: 0.9573 - val_accuracy: 0.6220 - 2s/epoch - 55ms/step
# Epoch 103/200
# 32/32 - 2s - loss: 0.9017 - accuracy: 0.6025 - val_loss: 0.9315 - val_accuracy: 0.5980 - 2s/epoch - 56ms/step
# Epoch 104/200
# 32/32 - 2s - loss: 0.8977 - accuracy: 0.6015 - val_loss: 0.9374 - val_accuracy: 0.6220 - 2s/epoch - 56ms/step
# Epoch 105/200
# 32/32 - 2s - loss: 0.8838 - accuracy: 0.6135 - val_loss: 0.9486 - val_accuracy: 0.6080 - 2s/epoch - 56ms/step
# Epoch 106/200
# 32/32 - 2s - loss: 0.8901 - accuracy: 0.6150 - val_loss: 0.9513 - val_accuracy: 0.6080 - 2s/epoch - 56ms/step
# Epoch 107/200
# 32/32 - 2s - loss: 0.9094 - accuracy: 0.6080 - val_loss: 0.8760 - val_accuracy: 0.6160 - 2s/epoch - 56ms/step
# Epoch 108/200
# 32/32 - 2s - loss: 0.8818 - accuracy: 0.6235 - val_loss: 0.9313 - val_accuracy: 0.5980 - 2s/epoch - 56ms/step
# Epoch 109/200
# 32/32 - 2s - loss: 0.8762 - accuracy: 0.6245 - val_loss: 0.8956 - val_accuracy: 0.6300 - 2s/epoch - 56ms/step
# Epoch 110/200
# 32/32 - 2s - loss: 0.8747 - accuracy: 0.6135 - val_loss: 0.8725 - val_accuracy: 0.6240 - 2s/epoch - 56ms/step
# Epoch
# Epoch 166/200
# 32/32 - 2s - loss: 0.7550 - accuracy: 0.6855 - val_loss: 0.8209 - val_accuracy: 0.6480 - 2s/epoch - 53ms/step
# Epoch 167/200
# 32/32 - 2s - loss: 0.7619 - accuracy: 0.6750 - val_loss: 0.8070 - val_accuracy: 0.6520 - 2s/epoch - 57ms/step
# Epoch 168/200
# 32/32 - 2s - loss: 0.7442 - accuracy: 0.6845 - val_loss: 0.8143 - val_accuracy: 0.6620 - 2s/epoch - 56ms/step
# Epoch 169/200
# 32/32 - 2s - loss: 0.7523 - accuracy: 0.6785 - val_loss: 0.8162 - val_accuracy: 0.6620 - 2s/epoch - 57ms/step
# Epoch 170/200
# 32/32 - 2s - loss: 0.7518 - accuracy: 0.6840 - val_loss: 0.8397 - val_accuracy: 0.6480 - 2s/epoch - 59ms/step
# Epoch 171/200
# 32/32 - 2s - loss: 0.7382 - accuracy: 0.6730 - val_loss: 0.8524 - val_accuracy: 0.6380 - 2s/epoch - 53ms/step
# Epoch 172/200
# 32/32 - 2s - loss: 0.7621 - accuracy: 0.6755 - val_loss: 0.8256 - val_accuracy: 0.6440 - 2s/epoch - 55ms/step
# Epoch 173/200
# 32/32 - 2s - loss: 0.7451 - accuracy: 0.6745 - val_loss: 0.8165 - val_accuracy: 0.6600 - 2s/epoch - 55ms/step
# Epoch 174/200
# 32/32 - 2s - loss: 0.7337 - accuracy: 0.6805 - val_loss: 0.8248 - val_accuracy: 0.6440 - 2s/epoch - 56ms/step
# Epoch 175/200
# 32/32 - 2s - loss: 0.7659 - accuracy: 0.6710 - val_loss: 0.8075 - val_accuracy: 0.6740 - 2s/epoch - 55ms/step
# Epoch 176/200
# 32/32 - 2s - loss: 0.7310 - accuracy: 0.6860 - val_loss: 0.8543 - val_accuracy: 0.6440 - 2s/epoch - 56ms/step
# Epoch 177/200
# 32/32 - 2s - loss: 0.7220 - accuracy: 0.6875 - val_loss: 0.8175 - val_accuracy: 0.6580 - 2s/epoch - 55ms/step
# Epoch 178/200
# 32/32 - 2s - loss: 0.7353 - accuracy: 0.6800 - val_loss: 0.8117 - val_accuracy: 0.6740 - 2s/epoch - 56ms/step
# Epoch 179/200
# 32/32 - 2s - loss: 0.7576 - accuracy: 0.6655 - val_loss: 0.8330 - val_accuracy: 0.6560 - 2s/epoch - 56ms/step
# Epoch 180/200
# 32/32 - 2s - loss: 0.7479 - accuracy: 0.6620 - val_loss: 0.8273 - val_accuracy: 0.6600 - 2s/epoch - 56ms/step
# Epoch 181/200
# 32/32 - 2s - loss: 0.7142 - accuracy: 0.6990 - val_loss: 0.8111 - val_accuracy: 0.6580 - 2s/epoch - 56ms/step
# Epoch 182/200
# 32/32 - 2s - loss: 0.7270 - accuracy: 0.6735 - val_loss: 0.8120 - val_accuracy: 0.6600 - 2s/epoch - 56ms/step
# Epoch 183/200
# 32/32 - 2s - loss: 0.7107 - accuracy: 0.6845 - val_loss: 0.7901 - val_accuracy: 0.6740 - 2s/epoch - 56ms/step
# Epoch 184/200
# 32/32 - 2s - loss: 0.7005 - accuracy: 0.6880 - val_loss: 0.7972 - val_accuracy: 0.6500 - 2s/epoch - 56ms/step
# Epoch 185/200
# 32/32 - 2s - loss: 0.7253 - accuracy: 0.6875 - val_loss: 0.8062 - val_accuracy: 0.6660 - 2s/epoch - 56ms/step
# Epoch 186/200
# 32/32 - 2s - loss: 0.7168 - accuracy: 0.6775 - val_loss: 0.8106 - val_accuracy: 0.6640 - 2s/epoch - 54ms/step
# Epoch 187/200
# 32/32 - 2s - loss: 0.7101 - accuracy: 0.6975 - val_loss: 0.7796 - val_accuracy: 0.6760 - 2s/epoch - 56ms/step
# Epoch 188/200
# 32/32 - 2s - loss: 0.7223 - accuracy: 0.6815 - val_loss: 0.7798 - val_accuracy: 0.6560 - 2s/epoch - 57ms/step
# Epoch 189/200
# 32/32 - 2s - loss: 0.7167 - accuracy: 0.6880 - val_loss: 0.7767 - val_accuracy: 0.6700 - 2s/epoch - 56ms/step
# Epoch 190/200
# 32/32 - 2s - loss: 0.7484 - accuracy: 0.6910 - val_loss: 0.8028 - val_accuracy: 0.6720 - 2s/epoch - 56ms/step
# Epoch 191/200
# 32/32 - 2s - loss: 0.7088 - accuracy: 0.6910 - val_loss: 0.8100 - val_accuracy: 0.6680 - 2s/epoch - 56ms/step
# Epoch 192/200
# 32/32 - 2s - loss: 0.7209 - accuracy: 0.6940 - val_loss: 0.7795 - val_accuracy: 0.6680 - 2s/epoch - 56ms/step
# Epoch 193/200
# 32/32 - 2s - loss: 0.7188 - accuracy: 0.6915 - val_loss: 0.8088 - val_accuracy: 0.6680 - 2s/epoch - 56ms/step
# Epoch 194/200
# 32/32 - 2s - loss: 0.6975 - accuracy: 0.6920 - val_loss: 0.7881 - val_accuracy: 0.6780 - 2s/epoch - 56ms/step
# Epoch 195/200
# 32/32 - 2s - loss: 0.7053 - accuracy: 0.6835 - val_loss: 0.7988 - val_accuracy: 0.6560 - 2s/epoch - 56ms/step
# Epoch 196/200
# 32/32 - 2s - loss: 0.7215 - accuracy: 0.6845 - val_loss: 0.8005 - val_accuracy: 0.6680 - 2s/epoch - 56ms/step
# Epoch 197/200
# 32/32 - 2s - loss: 0.7151 - accuracy: 0.6875 - val_loss: 0.8214 - val_accuracy: 0.6600 - 2s/epoch - 56ms/step
# Epoch 198/200
# 32/32 - 2s - loss: 0.7141 - accuracy: 0.6975 - val_loss: 0.7879 - val_accuracy: 0.6800 - 2s/epoch - 56ms/step
# Epoch 199/200
# 32/32 - 2s - loss: 0.7063 - accuracy: 0.6865 - val_loss: 0.8136 - val_accuracy: 0.6580 - 2s/epoch - 55ms/step
# Epoch 200/200
# 32/32 - 2s - loss: 0.7062 - accuracy: 0.6800 - val_loss: 0.7985 - val_accuracy: 0.6580 - 2s/epoch - 56ms/step

# %%
plot_model_accuracy(history)
plot_model_loss(history)
